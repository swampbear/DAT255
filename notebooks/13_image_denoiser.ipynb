# %% [markdown]
# # Autoencoder for image noise reduction
#
# Reducing noise in images (_denoising_) can be done in different ways, but one cool way is to train an [autoencoder](https://en.wikipedia.org/wiki/Autoencoder).
#
# Autoencoders are typically trained in an usupervised manner, which doesn't use any information about labels. In this case we will technically work with it in a supervised way, but we are never using information about the true image labels, which is interesting.
#
# Basically we want to make a model that can compress the information in an image, and then decompress it again. If we feed it a noisy image, the compression (_encoding_) step should pick up the relevant information, and the decompression (_decoding_) step reconstruct the image from the model's "ideal" of what the image looks like, which is free from noise. We can draw the model as something like this:
#
# ![image.png](data:image/png;base64,...)
#
# This notebook is based on the [Keras examples](https://keras.io/examples/), so have a look here for other computer vision problems.

# %% [markdown]
# ## Setup and data processing steps

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras import layers

# %% [markdown]
# Add some convenience functions for preprocessing and showing the images:

# %%
def preprocess(array):
    """Normalizes the supplied array and reshapes it."""
    array = array.astype("float32") / 255.0
    array = np.reshape(array, (len(array), 28, 28, 1))
    return array

def display(array1, array2):
    """Displays ten random images from each array."""
    n = 10
    indices = np.random.randint(len(array1), size=n)
    images1 = array1[indices, :]
    images2 = array2[indices, :]

    plt.figure(figsize=(20, 4))
    for i, (image1, image2) in enumerate(zip(images1, images2)):
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(image1.reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(image2.reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    plt.show()

# %% [markdown]
# An important function for this experiment is one that **adds noise** to out images. This allows us to create a dataset where we know a noise-free version of each image (which we start out with), and a noisy version, which we created ourselves.

# %%
def noise(array):
    """Adds random noise to each image in the supplied array."""
    noise_factor = 0.4
    noisy_array = array + noise_factor * np.random.normal(
        loc=0.0, scale=1.0, size=array.shape
    )

    return np.clip(noisy_array, 0.0, 1.0)

# %% [markdown]
# Load the MNIST dataset of handwritten digits.
#
# In this case we throw away the labels for each image, which we don't need.

# %%
(train_data, _), (test_data, _) = keras.datasets.mnist.load_data()

# Normalize and reshape the data
train_data = preprocess(train_data)
test_data = preprocess(test_data)

# Create a copy of the data with added noise
noisy_train_data = noise(train_data)
noisy_test_data = noise(test_data)

# Display the train data and a version of it with added noise
display(train_data, noisy_train_data)

# %% [markdown]
# ## Build the model
#
# Now for the exciting part: We want a model that can downsample and extract information, and then upsample it again to match the original dimensions of the image.

# %% [markdown]
# ### <span style="color: red; font-weight: bold;">Exercise:<span>
#
# Build a model that contains the following:
#
# - Two sequential blocks that contain a convolutional layer followed by a max-pooling layer. Use 32 filters with kernel size 3x3, and `padding='same'`. The pooling layer can have pool size 2x2.
# - A matching amount of `Conv2DTranspose` layers, that can upsample to the correct final dimensions. Try to find values of `kernel_size` and `strides` to achieve the correct output resolution. (Hint: look at the output shapes of the `MaxPooling` layers)
# - The final layer should be a 1x1 convolution layer with sigmoid activation function.

# %%
inputs = layers.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, 3, activation="relu", padding="same")(inputs)
x = layers.MaxPooling2D(2)(x)

x = layers.Conv2DTranspose(32, 3, strides=2, activation="relu", padding="same")(x)
x = layers.Conv2DTranspose(1, 2, strides=1, activation="sigmoid", padding="same")(x)

outputs = layers.Conv2D(1, 1, activation="sigmoid", padding="same")(x)
# Your model definition goes here

autoencoder = keras.Model(inputs, outputs)
autoencoder.compile(optimizer="adam", loss="binary_crossentropy")
autoencoder.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_20 (Conv2D)                   │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_14                  │ (None, 28, 28, 32)          │           9,248 │
# │ (Conv2DTranspose)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_15                  │ (None, 28, 28, 1)           │             129 │
# │ (Conv2DTranspose)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 28, 28, 1)           │               2 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,699 (37.89 KB)
#  Trainable params: 9,699 (37.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train the model on unmodified images
#
# First, let's test if the model can in fact compress the vital information in the images. Train it on the **noise-free** data, and then test if it can reconstruct images.

# %%
autoencoder.fit(
    x=train_data,
    y=train_data,
    epochs=50,
    batch_size=128,
    shuffle=True,
    validation_data=(test_data, test_data),
)
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 0.4137 - val_loss: 0.2804
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2660 - val_loss: 0.2385
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2311 - val_loss: 0.2173
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2113 - val_loss: 0.2001
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1947 - val_loss: 0.1835
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1783 - val_loss: 0.1676
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1631 - val_loss: 0.1529
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.1487 - val_loss: 0.1398
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1360 - val_loss: 0.1283
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1251 - val_loss: 0.1183
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1157 - val_loss: 0.1098
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.1074 - val_loss: 0.1025
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1006 - val_loss: 0.0963
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0948 - val_loss: 0.0909
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0897 - val_loss: 0.0864
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0853 - val_loss: 0.0825
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0817 - val_loss: 0.0792
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0786 - val_loss: 0.0764
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0757 - val_loss: 0.0739
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0735 - val_loss: 0.0719
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0715 - val_loss: 0.0701
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0699 - val_loss: 0.0686
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0685 - val_loss: 0.0673
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0672 - val_loss: 0.0663
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0662 - val_loss: 0.0653
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0653 - val_loss: 0.0645
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0646 - val_loss: 0.0638
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0639 - val_loss: 0.0632
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0633 - val_loss: 0.0627
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0629 - val_loss: 0.0622
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0624 - val_loss: 0.0619
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0620 - val_loss: 0.0616
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0618 - val_loss: 0.0613
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0615 - val_loss: 0.0611
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0612 - val_loss: 0.0608
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0612 - val_loss: 0.0607
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0610 - val_loss: 0.0606
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0607 - val_loss: 0.0604
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0608 - val_loss: 0.0603
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0606 - val_loss: 0.0602
# Epoch 41/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0605 - val_loss: 0.0601
# Epoch 42/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0605 - val_loss: 0.0600
# Epoch 43/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0604 - val_loss: 0.0601
# Epoch 44/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0603 - val_loss: 0.0600
# Epoch 45/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0602 - val_loss: 0.0599
# Epoch 46/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0601 - val_loss: 0.0598
# Epoch 47/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0602 - val_loss: 0.0598
# Epoch 48/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0600 - val_loss: 0.0597
# Epoch 49/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0600 - val_loss: 0.0597
# Epoch 50/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0599 - val_loss: 0.0597

# %% [markdown]
# ## Test the model
#
# Now test the model (again on noise-free data) and see if the output is euqal to the input. If it is, we have shown that the image can effectively be compressed through a machine-learning approach.

# %%
predictions = autoencoder.predict(test_data)
display(test_data, predictions)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ## Train on noisy data
#
# Now for the actual task -- train the model to perform de-noising. We run the same training as before, but now with noisy inputs.

# %%
autoencoder.fit(
    x=noisy_train_data,
    y=train_data,
    epochs=100,
    batch_size=128,
    shuffle=True,
    validation_data=(noisy_test_data, test_data),
)
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1307 - val_loss: 0.0979
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0982 - val_loss: 0.0963
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0967 - val_loss: 0.0956
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0960 - val_loss: 0.0950
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0956 - val_loss: 0.0947
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0952 - val_loss: 0.0945
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0949 - val_loss: 0.0942
# Epoch 8/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0948 - val_loss: 0.0944
# Epoch 9/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0945 - val_loss: 0.0939
# Epoch 10/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0941 - val_loss: 0.0937
# Epoch 11/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0943 - val_loss: 0.0937
# Epoch 12/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0940 - val_loss: 0.0934
# Epoch 13/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0941 - val_loss: 0.0932
# Epoch 14/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0937 - val_loss: 0.0931
# Epoch 15/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0936 - val_loss: 0.0931
# Epoch 16/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0935 - val_loss: 0.0930
# Epoch 17/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0937 - val_loss: 0.0930
# Epoch 18/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0934 - val_loss: 0.0927
# Epoch 19/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0932 - val_loss: 0.0926
# Epoch 20/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0932 - val_loss: 0.0926
# Epoch 21/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0931 - val_loss: 0.0925
# Epoch 22/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0929 - val_loss: 0.0924
# Epoch 23/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0931 - val_loss: 0.0927
# Epoch 24/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0930 - val_loss: 0.0923
# Epoch 25/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0930 - val_loss: 0.0922
# Epoch 26/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0927 - val_loss: 0.0922
# Epoch 27/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0929 - val_loss: 0.0923
# Epoch 28/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0928 - val_loss: 0.0923
# Epoch 29/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0926 - val_loss: 0.0920
# Epoch 30/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0926 - val_loss: 0.0920
# Epoch 31/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0924 - val_loss: 0.0921
# Epoch 32/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0925 - val_loss: 0.0921
# Epoch 33/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0926 - val_loss: 0.0918
# Epoch 34/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0925 - val_loss: 0.0918
# Epoch 35/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0924 - val_loss: 0.0921
# Epoch 36/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0924 - val_loss: 0.0919
# Epoch 37/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0925 - val_loss: 0.0918
# Epoch 38/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0923 - val_loss: 0.0917
# Epoch 39/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0924 - val_loss: 0.0916
# Epoch 40/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0922 - val_loss: 0.0916
# Epoch 41/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0922 - val_loss: 0.0917
# Epoch 42/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0922 - val_loss: 0.0915
# Epoch 43/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0922 - val_loss: 0.0915
# Epoch 44/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0922 - val_loss: 0.0916
# Epoch 45/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0921 - val_loss: 0.0915
# Epoch 46/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0921 - val_loss: 0.0915
# Epoch 47/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0920 - val_loss: 0.0914
# Epoch 48/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0920 - val_loss: 0.0913
# Epoch 49/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0921 - val_loss: 0.0914
# Epoch 50/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0919 - val_loss: 0.0913
# Epoch 51/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0919 - val_loss: 0.0914
# Epoch 52/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0917 - val_loss: 0.0913
# Epoch 53/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0917 - val_loss: 0.0913
# Epoch 54/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0918 - val_loss: 0.0912
# Epoch 55/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0916 - val_loss: 0.0912
# Epoch 56/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0917 - val_loss: 0.0912
# Epoch 57/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0916 - val_loss: 0.0911
# Epoch 58/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0916 - val_loss: 0.0914
# Epoch 59/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0916 - val_loss: 0.0911
# Epoch 60/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0915 - val_loss: 0.0911
# Epoch 61/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0918 - val_loss: 0.0911
# Epoch 62/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0916 - val_loss: 0.0911
# Epoch 63/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0917 - val_loss: 0.0912
# Epoch 64/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0917 - val_loss: 0.0910
# Epoch 65/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0915 - val_loss: 0.0910
# Epoch 66/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0915 - val_loss: 0.0911
# Epoch 67/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0915 - val_loss: 0.0910
# Epoch 68/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0916 - val_loss: 0.0914
# Epoch 69/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0916 - val_loss: 0.0909
# Epoch 70/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0915 - val_loss: 0.0909
# Epoch 71/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0915 - val_loss: 0.0909
# Epoch 72/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0913 - val_loss: 0.0910
# Epoch 73/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0914 - val_loss: 0.0908
# Epoch 74/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0913 - val_loss: 0.0910
# Epoch 75/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0916 - val_loss: 0.0908
# Epoch 76/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0914 - val_loss: 0.0910
# Epoch 77/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0915 - val_loss: 0.0908
# Epoch 78/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0915 - val_loss: 0.0908
# Epoch 79/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0914 - val_loss: 0.0908
# Epoch 80/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0912 - val_loss: 0.0908
# Epoch 81/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0912 - val_loss: 0.0907
# Epoch 82/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0911 - val_loss: 0.0910
# Epoch 83/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0914 - val_loss: 0.0911
# Epoch 84/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0914 - val_loss: 0.0908
# Epoch 85/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0911 - val_loss: 0.0906
# Epoch 86/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0913 - val_loss: 0.0908
# Epoch 87/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0910 - val_loss: 0.0908
# Epoch 88/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0912 - val_loss: 0.0908
# Epoch 89/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0913 - val_loss: 0.0906
# Epoch 90/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0911 - val_loss: 0.0910
# Epoch 91/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0911 - val_loss: 0.0906
# Epoch 92/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0912 - val_loss: 0.0908
# Epoch 93/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0912 - val_loss: 0.0906
# Epoch 94/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0909 - val_loss: 0.0907
# Epoch 95/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0913 - val_loss: 0.0908
# Epoch 96/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0912 - val_loss: 0.0906
# Epoch 97/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0910 - val_loss: 0.0905
# Epoch 98/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0910 - val_loss: 0.0907
# Epoch 99/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0910 - val_loss: 0.0905
# Epoch 100/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0911 - val_loss: 0.0905

# %% [markdown]
# ## The final test
#
# Try out our denoising model:

# %%
predictions = autoencoder.predict(noisy_test_data)
display(noisy_test_data, predictions)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
